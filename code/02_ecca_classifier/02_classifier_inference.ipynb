# %% [markdown]
# <a href="https://colab.research.google.com/github/malojan/edf_un_climate/blob/master/code/measurement/classifier_inference.ipynb?authuser=0" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Classifier inference on the UNGA corpus

# %% [markdown]
# Author : Malo Jan
#
# In this notebook, I use the ECCA classifier trained to predict sentences that are climate-related for inference on the rest of the United Nations General Assembly Corpus.

# %% [markdown]
# #### Setup

# %%
# check if on colab
try:
    import google.colab
    COLAB = True
except:
    COLAB=False
print('on colab:', COLAB)
# Out:
# on colab: True

# %%
# set working directory to base of repo

import os

if COLAB:
    from google.colab import drive
    drive.mount('/content/drive')  # Might need to adapt to your path
    if not os.getcwd().endswith("edf_un_climate"):
        os.chdir("drive/MyDrive/edf_un_climate")
else:
    if not os.getcwd().endswith("edf_un_climate"):
        os.chdir(os.path.dirname(os.path.dirname(os.getcwd())))
    print(os.getcwd())
# Out:
# Mounted at /content/drive

# %%
# Import packages

import pandas as pd
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from tqdm.auto import tqdm
from torch.nn.functional import softmax

# %% [markdown]
# #### Import data

# %%
df = pd.read_parquet("data/un_speeches_tokenized.parquet", engine = "pyarrow")

df
# Out:
#                   doc_id                                               text  \
# 0        ARG_01_1946.txt  At the resumption of the first session of the ...
# 1        ARG_01_1946.txt          Politics are determined by circumstances.
# 2        ARG_01_1946.txt  Accordingly, in making these remarks, we do no...
# 3        ARG_01_1946.txt  We hope that these remarks will be interpreted...
# 4        ARG_01_1946.txt  We are not sceptics, but our relative optimism...
# ...                  ...                                                ...
# 1319416  ZWE_79_2024.txt  The challenges we face are immense, but not in...
# 1319417  ZWE_79_2024.txt  By acting together, we can advance peace, prom...
# 1319418  ZWE_79_2024.txt  Zimbabwe stands ready to collaborate with all ...
# 1319419  ZWE_79_2024.txt  Let us work in unison, guided by the spirit of...
# 1319420  ZWE_79_2024.txt                                      I   thank you
#
#            year iso_code  session    country   name_of_person_speaking  \
# 0        1946.0      ARG      1.0  Argentina                  Mr. Arce
# 1        1946.0      ARG      1.0  Argentina                  Mr. Arce
# 2        1946.0      ARG      1.0  Argentina                  Mr. Arce
# 3        1946.0      ARG      1.0  Argentina                  Mr. Arce
# 4        1946.0      ARG      1.0  Argentina                  Mr. Arce
# ...         ...      ...      ...        ...                       ...
# 1319416  2024.0      ZWE     79.0   Zimbabwe  Frederick Makamure Shava
# 1319417  2024.0      ZWE     79.0   Zimbabwe  Frederick Makamure Shava
# 1319418  2024.0      ZWE     79.0   Zimbabwe  Frederick Makamure Shava
# 1319419  2024.0      ZWE     79.0   Zimbabwe  Frederick Makamure Shava
# 1319420  2024.0      ZWE     79.0   Zimbabwe  Frederick Makamure Shava
#
#                                 post  text_id                  id  word_count
# 0                               None        0   ARG_01_1946.txt_0          24
# 1                               None        1   ARG_01_1946.txt_1           5
# 2                               None        2   ARG_01_1946.txt_2          39
# 3                               None        3   ARG_01_1946.txt_3          12
# 4                               None        4   ARG_01_1946.txt_4          22
# ...                              ...      ...                 ...         ...
# 1319416  Minister of Foreign Affairs       64  ZWE_79_2024.txt_64           9
# 1319417  Minister of Foreign Affairs       65  ZWE_79_2024.txt_65          19
# 1319418  Minister of Foreign Affairs       66  ZWE_79_2024.txt_66          21
# 1319419  Minister of Foreign Affairs       67  ZWE_79_2024.txt_67          35
# 1319420  Minister of Foreign Affairs       68  ZWE_79_2024.txt_68           3
#
# [1319421 rows x 11 columns]

# %%
df = df[df['year'] >= 1985]

df_sample = df.sample(n=1000)

# %% [markdown]
# #### Inference on out-of-sample data

# %%
tokenizer = AutoTokenizer.from_pretrained("mljn/unga-climate-classifier")
model = AutoModelForSequenceClassification.from_pretrained("mljn/unga-climate-classifier")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/286 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/992 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/738M [00:00<?, ?B/s]

# %%
def classify_climate(df, text_column, model_name, batch_size=32):
    """
    Run inference on a pandas DataFrame using a Hugging Face model with batch processing.

    :param df: pandas DataFrame containing the text data.
    :param text_column: Name of the column in df that contains the text.
    :param model_name: Name of the model on Hugging Face Model Hub.
    :param batch_size: Size of batches for processing.
    :return: DataFrame with original data and new columns 'prediction' and 'probability'.
    """
    # Load model and tokenizer
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSequenceClassification.from_pretrained(model_name)
    model.eval()

    # Prepare device (GPU or CPU)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    # Store results
    results = []

    for i in tqdm(range(0, len(df), batch_size), desc="Processing"):
        batch_texts = df.iloc[i:i + batch_size][text_column].tolist()
        inputs = tokenizer(batch_texts, padding=True, truncation=True, return_tensors="pt").to(device)

        with torch.no_grad():
            outputs = model(**inputs)
            probs = softmax(outputs.logits, dim=1)
            predictions = torch.argmax(probs, dim=1).tolist()
            probabilities = probs.max(dim=1).values.tolist()

        results.extend(zip(df.iloc[i:i + batch_size]['id'], predictions, probabilities))

    # Convert results to DataFrame
    results_df = pd.DataFrame(results, columns=['id', 'prediction', 'probability'])

    # Merge with original DataFrame
    final_df = df.merge(results_df, on='id', how='left')

    return final_df

# %%
model_name = "mljn/unga-climate-classifier"  # Replace with your model's name
df_predicted = classify_climate(df, 'text', model_name)
# Out:
# Processing:   0%|          | 0/21173 [00:00<?, ?it/s]

# %%
df_predicted
# Out:
#                  doc_id                                               text  \
# 0       AFG_40_1985.txt  I wish at the outset to congratulate the Presi...
# 1       AFG_40_1985.txt  While offering the full co-operation of the de...
# 2       AFG_40_1985.txt  May I also put on record our appreciation of t...
# 3       AFG_40_1985.txt  On the grievous and sad occasion of the traged...
# 4       AFG_40_1985.txt  of the basic principles of the policy of the D...
# ...                 ...                                                ...
# 677521  ZWE_79_2024.txt  The challenges we face are immense, but not in...
# 677522  ZWE_79_2024.txt  By acting together, we can advance peace, prom...
# 677523  ZWE_79_2024.txt  Zimbabwe stands ready to collaborate with all ...
# 677524  ZWE_79_2024.txt  Let us work in unison, guided by the spirit of...
# 677525  ZWE_79_2024.txt                                      I   thank you
#
#           year iso_code  session      country   name_of_person_speaking  \
# 0       1985.0      AFG     40.0  Afghanistan                  Mr. Dost
# 1       1985.0      AFG     40.0  Afghanistan                  Mr. Dost
# 2       1985.0      AFG     40.0  Afghanistan                  Mr. Dost
# 3       1985.0      AFG     40.0  Afghanistan                  Mr. Dost
# 4       1985.0      AFG     40.0  Afghanistan                  Mr. Dost
# ...        ...      ...      ...          ...                       ...
# 677521  2024.0      ZWE     79.0     Zimbabwe  Frederick Makamure Shava
# 677522  2024.0      ZWE     79.0     Zimbabwe  Frederick Makamure Shava
# 677523  2024.0      ZWE     79.0     Zimbabwe  Frederick Makamure Shava
# 677524  2024.0      ZWE     79.0     Zimbabwe  Frederick Makamure Shava
# 677525  2024.0      ZWE     79.0     Zimbabwe  Frederick Makamure Shava
#
#                                post  text_id                  id  word_count  \
# 0                              None        0   AFG_40_1985.txt_0          23
# 1                              None        1   AFG_40_1985.txt_1          25
# 2                              None        2   AFG_40_1985.txt_2          30
# 3                              None        3   AFG_40_1985.txt_3          39
# 4                              None        4   AFG_40_1985.txt_4          30
# ...                             ...      ...                 ...         ...
# 677521  Minister of Foreign Affairs       64  ZWE_79_2024.txt_64           9
# 677522  Minister of Foreign Affairs       65  ZWE_79_2024.txt_65          19
# 677523  Minister of Foreign Affairs       66  ZWE_79_2024.txt_66          21
# 677524  Minister of Foreign Affairs       67  ZWE_79_2024.txt_67          35
# 677525  Minister of Foreign Affairs       68  ZWE_79_2024.txt_68           3
#
#         prediction  probability
# 0                0     0.993638
# 1                0     0.995708
# 2                0     0.995496
# 3                0     0.995881
# 4                0     0.995613
# ...            ...          ...
# 677521           0     0.994195
# 677522           0     0.966357
# 677523           0     0.996158
# 677524           0     0.995390
# 677525           0     0.968430
#
# [677526 rows x 13 columns]

# %% [markdown]
# #### Save predictions

# %%
df_predicted.to_parquet('data/un_predictions_all.parquet', index=False)
